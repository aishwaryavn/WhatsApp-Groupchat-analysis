# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/Thesis - Gasperis/Non-Flooded/image")
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/Thesis - Gasperis/Non-Flooded/image

# %%
from IPython.display import Image
Image(filename='/content/drive/MyDrive/Colab Notebooks/Thesis - Gasperis/Non-Flooded/mask/9365_lab.png', width=300,height=200)

# %%
path = "/content/drive/MyDrive/Colab Notebooks/Thesis - Gasperis/Non-Flooded/mask/9365_lab.png"
img = cv.imread(path)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(img)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=4000x3000 at 0x7F5EBFE1E350>

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
equ = cv.cvtColor(img, cv2.COLOR_BGR2GRAY)
equ = cv.equalizeHist(equ)

# %%
cv2_imshow(equ)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=4000x3000 at 0x7F5EBFD72250>

# %%
hist,bins = np.histogram(equ.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(equ.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
